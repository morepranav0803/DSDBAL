# %%
import pandas as pd

# %%
x=pd.DataFrame({"RollNo":[1,2,3],"Name":["Ram","Sham","Pranav"]})

# %%
x
# Out:
#    RollNo    Name
# 0       1     Ram
# 1       2    Sham
# 2       3  Pranav

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RollNo  3 non-null      int64
#  1   Name    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
x.describe()
# Out:
#        RollNo
# count     3.0
# mean      2.0
# std       1.0
# min       1.0
# 25%       1.5
# 50%       2.0
# 75%       2.5
# max       3.0

# %%
x.isnull()
# Out:
#    RollNo   Name
# 0   False  False
# 1   False  False
# 2   False  False

# %%
x=pd.DataFrame({"RollNo":[1,2,3],"Name":["Ram","Sham","Pranav"]})
x
# Out:
#    RollNo    Name
# 0       1     Ram
# 1       2    Sham
# 2       3  Pranav

# %%
x.dropnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3388\3081089534.py in ?()
# ----> 1 x.dropnull()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dropnull'

# %%
x.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
x
# Out:
#    RollNo    Name
# 0       1     Ram
# 1       2    Sham
# 2       3  Pranav

# %%
x.head(2)
# Out:
#    RollNo  Name
# 0       1   Ram
# 1       2  Sham

# %%
x.tail(1)
# Out:
#    RollNo    Name
# 2       3  Pranav

# %%
x.tail(2)
# Out:
#    RollNo    Name
# 1       2    Sham
# 2       3  Pranav

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x.RollNo)
# Out:
# pandas.core.series.Series

# %%
type(x.Name)
# Out:
# pandas.core.series.Series
