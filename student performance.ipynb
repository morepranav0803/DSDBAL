# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/morep/OneDrive/Documents/Book1.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0           53             64             75               83         44
# 1           61             63             66               86         60
# 2           95             83             87               73         86
# 3           76             43             95               58         79
# 4           60             54             88               41         72
# ..         ...            ...            ...              ...        ...
# 84          80             76            100               67         46
# 85          63             84             95               93         47
# 86          47             72             94               81         47
# 87          57             84             70               41         76
# 88          40             51             41               46         60
#
#     Placement_Offer
# 0                66
# 1                45
# 2                47
# 3                78
# 4                58
# ..              ...
# 84               87
# 85              100
# 86               43
# 87               97
# 88               60
#
# [89 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     int64
#  1   Reading_Score    89 non-null     int64
#  2   Writing_Score    89 non-null     int64
#  3   Placement_Score  89 non-null     int64
#  4   Club_Join        89 non-null     int64
#  5   Placement_Offer  89 non-null     int64
# dtypes: int64(6)
# memory usage: 4.3 KB

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0        False          False          False            False      False
# 1        False          False          False            False      False
# 2        False          False          False            False      False
# 3        False          False          False            False      False
# 4        False          False          False            False      False
# ..         ...            ...            ...              ...        ...
# 84       False          False          False            False      False
# 85       False          False          False            False      False
# 86       False          False          False            False      False
# 87       False          False          False            False      False
# 88       False          False          False            False      False
#
#     Placement_Offer
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 84            False
# 85            False
# 86            False
# 87            False
# 88            False
#
# [89 rows x 6 columns]

# %%
df.Math_Score
# Out:
# 0     53
# 1     61
# 2     95
# 3     76
# 4     60
#       ..
# 84    80
# 85    63
# 86    47
# 87    57
# 88    40
# Name: Math_Score, Length: 89, dtype: int64

# %%
df.Math_Score.min
# Out:
# <bound method Series.min of 0     53
# 1     61
# 2     95
# 3     76
# 4     60
#       ..
# 84    80
# 85    63
# 86    47
# 87    57
# 88    40
# Name: Math_Score, Length: 89, dtype: int64>

# %%
x=df.Math_Score.min

# %%
x
# Out:
# <bound method Series.min of 0     53
# 1     61
# 2     95
# 3     76
# 4     60
#       ..
# 84    80
# 85    63
# 86    47
# 87    57
# 88    40
# Name: Math_Score, Length: 89, dtype: int64>

# %%
y=df.Math_Score.fillna(x)

# %%
y
# Out:
# 0     53
# 1     61
# 2     95
# 3     76
# 4     60
#       ..
# 84    80
# 85    63
# 86    47
# 87    57
# 88    40
# Name: Math_Score, Length: 89, dtype: int64

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Math_Score         0
# Reading_Score      0
# Writing_Score      0
# Placement_Score    0
# Club_Join          0
# Placement_Offer    0
# dtype: int64

# %%
df.Math_Score.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Writing_Score.min()
# Out:
# 40

# %%
x=df.Writing_Score.min()

# %%
y=df.Writing_Score.fillna(x)

# %%
y
# Out:
# 0      75
# 1      66
# 2      87
# 3      95
# 4      88
#      ...
# 84    100
# 85     95
# 86     94
# 87     70
# 88     41
# Name: Writing_Score, Length: 89, dtype: int64

# %%
df.Placement_Score.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Name: Placement_Score, Length: 89, dtype: bool

# %%
df.Placement_Score.isnull().sum()
# Out:
# np.int64(0)

# %%
x=df.Placement_Score.min()

# %%
x
# Out:
# 41

# %%
y=df.Placement_Score.fillna(x)
